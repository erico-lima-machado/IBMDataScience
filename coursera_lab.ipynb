# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Erico de Lima Machado**
# Automation Engineer

# %% [markdown]
# *I am interested in data science because it can help me to get my job done as an automation engineer in an easier way. Failure analysis, plant monitoring and other tasks can be partially or fully automated with data science tools. This will grant me some free time...to study and work more with data science :-(*

# %% [markdown]
# ### Guess what the code below does:

# %%
print ("hello, world!")
# Out:
# hello, world!

# %% [markdown]
# After my display of deep knowledge of Python, I will show off some markdown skills.
# Courtesy of:
# https://ingeh.medium.com/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed
#
# **Numbered list**
# 1. One
# 2. Two
# 3. Three
#
# **Bullet list**
# - One
# - Two
# - Three
#     - Three.1
#     - Three.2
#     - Three.3
# - Four
# - Five
#
# **Picture**
#
# ![Captura%20de%20Tela%202022-07-14%20a%CC%80s%2009.27.34.png](attachment:Captura%20de%20Tela%202022-07-14%20a%CC%80s%2009.27.34.png)
# This is me, doing what I should do instead of studying data science, but unfortunately it doesn't pay my bills.
#
# **Table**
#
# | Number | Tag  | Range   | Unit  | Interlock?   |
# |---:|:-------------|:-----------|:------|:------|
# | 1 | PIT-101 | 0 - 100      | Barg  | Y     |
# | 2 | PIT-102  | 0 - 200    | PSIg  | N    |
